# %% [markdown]
# ## Time Series Forecasting with FEATURES.CSV
#
# data: wallmart sales forecast datasets

# %%
import pandas as pd
from pandas import Series

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import LSTM
from keras.layers import GlobalAveragePooling1D

from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import TimeDistributed
# Out:
# Using TensorFlow backend.

# %%
# Load dataframe
df = pd.read_csv("features.csv")
df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df = df[['Date', 'Temperature']]
df = df.groupby(['Date']).mean()
df = df.sort_index(axis=0, level=None, ascending=True)

# %%
df.head()
# Out:
#             Temperature
# Date
# 2010-02-05    34.037333
# 2010-02-12    34.151333
# 2010-02-19    37.719778
# 2010-02-26    39.243556
# 2010-03-05    42.917333

# %%
# Converting the index as date
df.index = pd.to_datetime(df.index)

# Visualize
plt.figure(figsize=(10, 6))
df['Temperature'].plot();

# %%
# For the model split data fro trainig and testing that will be used to check the prediction
split_date = pd.Timestamp('2013-01-01')
df =  df['Temperature']
train = df.loc[:split_date]
test = df.loc[split_date:]
plt.figure(figsize=(10, 6))
ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])

# %%
len(df) # 182 
df.head() # starts from 2010-02-05
df.tail() # finish at 2013-07-26
len(train) # 152
len(test) # 30
# Out:
# 30

# %% [markdown]
# # CNN model
#
# ### Data normalization

# %%
# Prepare data for the model
train_values = train.values
test_values = test.values

train_values = train_values.reshape(-1, 1)
test_values = test_values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0, 1))
train_nor = scaler.fit_transform(train_values)
test_nor = scaler.fit_transform(test_values)

# %%
print('train data: ', train_nor[0:3])
print('test data: ', test_nor[0:3])
# Out:
# train data:  [[0.06879594]
#  [0.07100116]
#  [0.14002923]]
# test data:  [[0.        ]
#  [0.14818229]
#  [0.07650678]]

# %% [markdown]
# ### Create data sequences to pass to the models
#
# In this example we create 7-values sequences (one week) to predict the following value

# %%
FORWARD_STEPS = 7 # the number of values used for 1 prediction

def convert_to_Xy_1d(data, feature_idx, n_input=FORWARD_STEPS, n_output=1):
    X, y = [],[]
    in_start = 0
    for i in range(len(data)):
        in_end = in_start + n_input
        out_end = in_end + n_output
        if out_end < len(data):
            x_input = data[in_start:in_end, feature_idx]
            x_input = x_input.reshape((len(x_input), 1)) # column vector
            X.append(x_input)
            y.append(data[in_end:out_end, feature_idx])
        # step forward one unit
        in_start += 1
    return np.array(X), np.array(y)

# %%
def convert_to_array_after_prediction(seq_array, forward_steps = FORWARD_STEPS):
    seq_result = np.zeros((forward_steps,), dtype=int)
    seq_result = seq_result.tolist()
    for i in range(0, len(seq_array)):
        seq_result.append(seq_array[i][0])
    return seq_result

# %%
def convert_to_array(seq_array, forward_steps = FORWARD_STEPS):
    seq_result = []
    for i in range(0, len(seq_array)):
        seq_result.append(seq_array[i][0])
    return seq_result

# %%
# create train examples
trainX, trainy = convert_to_Xy_1d(train_nor, 0)
print('train input: ', trainX[0])
print('train output: ', trainy[0])
# Out:
# train input:  [[0.06879594]
#  [0.07100116]
#  [0.14002923]
#  [0.16950522]
#  [0.24057086]
#  [0.32791128]
#  [0.3766926 ]]
# train output:  [0.34805055]

# %%
# the same formal should be for the train examples
testX, testy = convert_to_Xy_1d(test_nor, 0)
print(testX[0], testy[0])
# Out:
# [[0.        ]
#  [0.14818229]
#  [0.07650678]
#  [0.13515119]
#  [0.24121287]
#  [0.20953044]
#  [0.17346441]] [0.16935119]

# %% [markdown]
# ### Find parameters and reshape examples for CNN model

# %%
trainX_for_cnn = trainX
testX_for_cnn = testX

# %%
n_timesteps, n_features, n_outputs = trainX_for_cnn.shape[1], trainX_for_cnn.shape[2], trainy.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 7 1 1

# %%
print(trainX_for_cnn.shape, trainy.shape)
print(trainX_for_cnn[0].shape, trainy[0].shape)
# Out:
# (144, 7, 1) (144, 1)
# (7, 1) (1,)

# %%
# Create model
cnn_model = Sequential()

cnn_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features))) #same as trainX[0].shape 
cnn_model.add(MaxPooling1D(pool_size=2))

cnn_model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
cnn_model.add(GlobalAveragePooling1D())

cnn_model.add(Dense(50, activation='relu'))
cnn_model.add(Dense(n_outputs))
cnn_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = cnn_model.fit(trainX_for_cnn, trainy, epochs=100, batch_size=1, verbose=2, callbacks=[early_stop], shuffle=False)
# Out:
# WARNING:tensorflow:From /Users/kkhvatov/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/kkhvatov/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 1s - loss: 0.1025 - acc: 0.0139
# Epoch 2/100
#  - 1s - loss: 0.0567 - acc: 0.0139
# Epoch 3/100
#  - 0s - loss: 0.0531 - acc: 0.0139
# Epoch 4/100
#  - 0s - loss: 0.0510 - acc: 0.0139
# Epoch 5/100
#  - 0s - loss: 0.0463 - acc: 0.0139
# Epoch 6/100
#  - 0s - loss: 0.0442 - acc: 0.0139
# Epoch 7/100
#  - 0s - loss: 0.0404 - acc: 0.0139
# Epoch 8/100
#  - 0s - loss: 0.0327 - acc: 0.0139
# Epoch 9/100
#  - 0s - loss: 0.0291 - acc: 0.0139
# Epoch 10/100
#  - 0s - loss: 0.0257 - acc: 0.0139
# Epoch 11/100
#  - 1s - loss: 0.0225 - acc: 0.0139
# Epoch 12/100
#  - 1s - loss: 0.0208 - acc: 0.0139
# Epoch 13/100
#  - 0s - loss: 0.0114 - acc: 0.0139
# Epoch 14/100
#  - 0s - loss: 0.0137 - acc: 0.0139
# Epoch 15/100
#  - 0s - loss: 0.0078 - acc: 0.0139
# Epoch 16/100
#  - 0s - loss: 0.0039 - acc: 0.0139
# Epoch 17/100
#  - 0s - loss: 0.0049 - acc: 0.0139
# Epoch 18/100
#  - 0s - loss: 0.0042 - acc: 0.0139
# Epoch 19/100
#  - 0s - loss: 0.0037 - acc: 0.0139
# Epoch 20/100
#  - 0s - loss: 0.0042 - acc: 0.0139
# Epoch 21/100
#  - 0s - loss: 0.0040 - acc: 0.0139
# Epoch 22/100
#  - 0s - loss: 0.0039 - acc: 0.0139
# Epoch 00022: early stopping

# %%
# calculate prediction
y_pred_test_cnn = cnn_model.predict(testX)
y_pred_train_cnn = cnn_model.predict(trainX)

# %%
y_pred_on_test = convert_to_array(y_pred_test_cnn)
y_pred_on_train = convert_to_array(y_pred_train_cnn)

# %%
# All train period
plt.figure(figsize=(10, 6))
plt.plot(trainy, label='True')
plt.plot(y_pred_on_train, label='CNN')
plt.title("CNN's Prediction")
plt.xlabel('Observation')
plt.ylabel('Temperature')
plt.legend()
plt.show();

# %%
# All train period
plt.figure(figsize=(10, 6))
plt.plot(testy, label='True')
plt.plot(y_pred_on_test, label='CNN')
plt.title("CNN's Prediction")
plt.xlabel('Observation')
plt.ylabel('Temperature')
plt.legend()
plt.show();

# %%
# When 𝑅2 equals 1 it means that the model is able to fully recreate dependent variable,
#when it equals 0, it means that the model completely failed at this task.
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(trainy, y_pred_train_cnn)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(testy, y_pred_test_cnn)))
# Out:
# The R2 score on the Train set is:	0.949
# The R2 score on the Test set is:	0.952

# %% [markdown]
# # LSTM model
#
# We will use the same data after normalization and creating sequences of examples: trainX, trainy, testX, testy

# %%
# reshape input to be [samples, time steps, features]
trainX_for_lstm = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX_for_lstm = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX_for_lstm.shape)
print(testX_for_lstm.shape)
# Out:
# (144, 1, 7)
# (22, 1, 7)

# %%
# create and fit the LSTM network
# input shape = (1, forward_steps)
# a layer with 4 LSTM blocks 
lstm_model = Sequential()
lstm_model.add(LSTM(4, input_shape=(1, FORWARD_STEPS)))
lstm_model.add(Dense(50, activation='relu'))
lstm_model.add(Dense(n_outputs))

lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = lstm_model.fit(trainX_for_lstm, trainy, epochs=100, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 4s 24ms/step - loss: 0.1504 - acc: 0.0069
# Epoch 2/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0428 - acc: 0.0139
# Epoch 3/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0327 - acc: 0.0139
# Epoch 4/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0268 - acc: 0.0139
# Epoch 5/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0225 - acc: 0.0139
# Epoch 6/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0188 - acc: 0.0139
# Epoch 7/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0160 - acc: 0.0139
# Epoch 8/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0119 - acc: 0.0139
# Epoch 9/100
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0084 - acc: 0.0139
# Epoch 10/100
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0058 - acc: 0.0139
# Epoch 11/100
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0046 - acc: 0.0139
# Epoch 12/100
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0042 - acc: 0.0139
# Epoch 13/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0041 - acc: 0.0139
# Epoch 14/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0042 - acc: 0.0139
# Epoch 15/100
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0042 - acc: 0.0139
# Epoch 16/100
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0041 - acc: 0.0139
# Epoch 00016: early stopping

# %%
y_pred_test_lstm = lstm_model.predict(testX_for_lstm)
y_train_pred_lstm = lstm_model.predict(trainX_for_lstm)

# %%
plt.figure(figsize=(10, 6))
plt.plot(testy, label='True')
plt.plot(y_pred_test_lstm, label='LSTM')
plt.title("LSTM Neural Network Prediction")
plt.xlabel('Observation')
plt.ylabel('Corn price')
plt.legend()
plt.show();

# %%
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(trainy, y_train_pred_lstm)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(testy, y_pred_test_lstm)))
# Out:
# The R2 score on the Train set is:	0.952
# The R2 score on the Test set is:	0.960

# %% [markdown]
# # CNN Long Short-Term Memory Networks
#
# The CNN LSTM architecture involves using Convolutional Neural Network (CNN) layers for feature extraction on input data combined with LSTMs to support sequence prediction.

# %%
# reshape from [samples, timesteps] into [samples, subsequences, timesteps, features]
n_features = 1
n_seq = 1
n_steps = 7
trainX_for_cnn_lstm = trainX.reshape((trainX.shape[0], n_seq, n_steps, n_features))
testX_for_cnn_lstm = testX.reshape((testX.shape[0], n_seq, n_steps, n_features))

# %%
print('Train')
print(trainX_for_cnn_lstm[0].shape)
print(trainX_for_cnn_lstm[0])

print('Test')
print(trainy[0].shape)
print(trainy[0])
# Out:
# Train
# (1, 7, 1)
# [[[0.06879594]
#   [0.07100116]
#   [0.14002923]
#   [0.16950522]
#   [0.24057086]
#   [0.32791128]
#   [0.3766926 ]]]
# Test
# (1,)
# [0.34805055]

# %%
cnn_lstm_model = Sequential()

cnn_lstm_model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_timesteps, n_features)))
cnn_lstm_model.add(MaxPooling1D(pool_size=2))

cnn_lstm_model.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
cnn_lstm_model.add(Dense(50))

cnn_lstm_model.add(TimeDistributed(Flatten()))
cnn_lstm_model.add(LSTM(4, activation='relu'))

cnn_lstm_model.add(Dense(n_outputs))
cnn_lstm_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history = cnn_lstm_model.fit(trainX_for_cnn, trainy, epochs=100, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/100
# 144/144 [==============================] - 4s 28ms/step - loss: 0.0870 - acc: 0.0139
# Epoch 2/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0629 - acc: 0.0139
# Epoch 3/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0527 - acc: 0.0139
# Epoch 4/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0459 - acc: 0.0139
# Epoch 5/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0441 - acc: 0.0139
# Epoch 6/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0354 - acc: 0.0139
# Epoch 7/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0314 - acc: 0.0139
# Epoch 8/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0265 - acc: 0.0139
# Epoch 9/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0224 - acc: 0.0139
# Epoch 10/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0182 - acc: 0.0139
# Epoch 11/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0143 - acc: 0.0139
# Epoch 12/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0109 - acc: 0.0139
# Epoch 13/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0082 - acc: 0.0139
# Epoch 14/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0063 - acc: 0.0139
# Epoch 15/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0053 - acc: 0.0139
# Epoch 16/100
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0049 - acc: 0.0139
# Epoch 17/100
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0051 - acc: 0.0139
# Epoch 18/100
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0048 - acc: 0.0139
# Epoch 19/100
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0046 - acc: 0.0139
# Epoch 20/100
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0047 - acc: 0.0139
# Epoch 21/100
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0048 - acc: 0.0139
# Epoch 00021: early stopping

# %%
# calculate prediction
y_pred_test_cnn_lstm = cnn_lstm_model.predict(testX_for_cnn)
y_train_pred_cnn_lstm = cnn_lstm_model.predict(trainX_for_cnn)

# %%
plt.figure(figsize=(10, 6))
plt.plot(testy, label='True')
plt.plot(y_pred_test_cnn_lstm, label='CNN_LSTM')
plt.title("LSTM Neural Network Prediction")
plt.xlabel('Observation')
plt.ylabel('Corn price')
plt.legend()
plt.show();

# %%
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(trainy, y_train_pred_cnn_lstm)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(testy, y_pred_test_cnn_lstm)))
# Out:
# The R2 score on the Train set is:	0.940
# The R2 score on the Test set is:	0.954
